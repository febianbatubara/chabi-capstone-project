# %%
answer = translate_back(result)

animal = pd.read_excel("drive/My Drive/Capstone Project/CHABI/dataset/Animal_character.xlsx")

animal_char = animal['Animal']
mbti = animal['Type']
explanation = animal['Explain']
youare = animal['Unique']
recom = animal['Video']

def myAnimal(answer):
    char = ""
    if(answer == mbti[0]):
        print("You are a ", animal_char[0])
        print(explanation[0])
        print("You look ", youare[0])
        print("To grow your character, we offer you to open this : ", recom[0])
    if(answer == mbti[1]):
        print("You are a ", animal_char[1])
        print(explanation[1])
        print("You look ", youare[1])
        print("To grow your character, we offer you to open this : ", recom[1])
    if(answer == mbti[2]):
        print("You are a ", animal_char[2])
        print(explanation[2])
        print("You look ", youare[2])
        print("To grow your character, we offer you to open this : ", recom[2])
    if(answer == mbti[3]):
        print("You are a ", animal_char[3])
        print(explanation[3])
        print("You look ", youare[3])
        print("To grow your character, we offer you to open this : ", recom[3])
    if(answer == mbti[4]):
        print("You are a ", animal_char[4])
        print(explanation[4])
        print("You look ", youare[4])
        print("To grow your character, we offer you to open this : ", recom[4])
    if(answer == mbti[5]):
        print("You are a ", animal_char[5])
        print(explanation[5])
        print("You look ", youare[5])
        print("To grow your character, we offer you to open this : ", recom[5])
    if(answer == mbti[6]):
        print("You are a ", animal_char[6])
        print(explanation[6])
        print("You look ", youare[6])
        print("To grow your character, we offer you to open this : ", recom[6])
    if(answer == mbti[7]):
        print("You are a ", animal_char[7])
        print(explanation[7])
        print("You look ", youare[7])
        print("To grow your character, we offer you to open this : ", recom[7])
    if(answer == mbti[8]):
        print("You are a ", animal_char[8])
        print(explanation[8])
        print("You look ", youare[8])
        print("To grow your character, we offer you to open this : ", recom[8])
    if(answer == mbti[9]):
        print("You are a ", animal_char[9])
        print(explanation[9])
        print("You look ", youare[9])
        print("To grow your character, we offer you to open this : ", recom[9])
    if(answer == mbti[10]):
        print("You are a ", animal_char[10])
        print(explanation[10])
        print("You look ", youare[10])
        print("To grow your character, we offer you to open this : ", recom[10])
    if(answer == mbti[11]):
        print("You are a ", animal_char[11])
        print(explanation[11])
        print("You look ", youare[11])
        print("To grow your character, we offer you to open this : ", recom[11])
    if(answer == mbti[12]):
        print("You are a ", animal_char[12])
        print(explanation[12])
        print("You look ", youare[12])
        print("To grow your character, we offer you to open this : ", recom[12])
    if(answer == mbti[13]):
        print("You are a ", animal_char[13])
        print(explanation[13])
        print("You look ", youare[13])
        print("To grow your character, we offer you to open this : ", recom[13])
    if(answer == mbti[14]):
        print("You are a ", animal_char[14])
        print(explanation[14])
        print("You look ", youare[14])
        print("To grow your character, we offer you to open this : ", recom[14])
    if(answer == mbti[15]):
        print("You are a ", animal_char[15])
        print(explanation[15])
        print("You look ", youare[15])
        print("To grow your character, we offer you to open this : ", recom[15])

myAnimal(answer)
